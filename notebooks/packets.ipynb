# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

import OpenAEM

# %%
distance = 0.4
alpha = np.deg2rad(10.0)

neddies = 7
h0 = 1.0
heights  = np.array([h0 - i*distance*np.tan(alpha) for i in range(neddies)])

beta = np.deg2rad(45.0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.axis('equal')
for i in range(neddies):
    ax.plot([-i*distance, -i*distance + heights[i]*np.tan(beta)], [0.0, heights[i]], 'k-')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a = np.zeros((4, 3))
print(np.size(a, axis=0))
# Out:
# 4
